# %%
import re
import pandas as pd
import numpy as np

# %%
DNA_AA_map = {"TTT":"F", "TTC":"F", "TTA":"L", "TTG":"L",
              "TCT":"S", "TCC":"S", "TCA":"S", "TCG":"S",
              "TAT":"Y", "TAC":"Y", "TAA":".", "TAG":".",
              "TGT":"C", "TGC":"C", "TGA":".", "TGG":"W",
              "CTT":"L", "CTC":"L", "CTA":"L", "CTG":"L",
              "CCT":"P", "CCC":"P", "CCA":"P", "CCG":"P",
              "CAT":"H", "CAC":"H", "CAA":"Q", "CAG":"Q",
              "CGT":"R", "CGC":"R", "CGA":"R", "CGG":"R",
              "ATT":"I", "ATC":"I", "ATA":"I", "ATG":"M",
              "ACT":"T", "ACC":"T", "ACA":"T", "ACG":"T",
              "AAT":"N", "AAC":"N", "AAA":"K", "AAG":"K",
              "AGT":"S", "AGC":"S", "AGA":"R", "AGG":"R",
              "GTT":"V", "GTC":"V", "GTA":"V", "GTG":"V",
              "GCT":"A", "GCC":"A", "GCA":"A", "GCG":"A",
              "GAT":"D", "GAC":"D", "GAA":"E", "GAG":"E",
              "GGT":"G", "GGC":"G", "GGA":"G", "GGG":"G", }

base_editing_key = {"CBE": ["C", "T"], 
                      "ABE": ["A", "G"]
                     }

bases = 'ACGT'
complements = {'A':'T', 'T':'A', 'G':'C', 'C':'G', 
                   'a':'t', 't':'a', 'g':'c', 'c':'g'}
cas_key = {'Sp': 'NGG', 'SpG': 'NGN', 'SpRY': 'NNN'}

def DNA_to_AA(seq): 
    aa_seq = ''
    for i in range(len(seq)//3): 
        codon = seq[(i*3):(i*3)+3].replace("T", "U")
        aa_seq += DNA_AA_map[codon]
    return aa_seq

def rev_complement(complements, seq): 
    compl = ''
    for i in range(len(seq)): 
        compl += complements[seq[i]]
    return compl[::-1]

def complement(complements, seq): 
    compl = ''
    for i in range(len(seq)): 
        compl += complements[seq[i]]
    return compl

# %%
class Gene_BaseEditing(): 
    
    def __init__(self, filepath, output_dir=''): 
        f = open(filepath, "r")
        self.file_content = f.read()
        self.exons_extra, self.exons = self.parse_exons()
    
    def parse_exons(self): 
        exons_extra = []
        i = -1
        for line in self.file_content.split('\n'): 
            if len(line) > 0 and line[0] == '>': 
                exons_extra.append('')
                i += 1
            else: 
                exons_extra[i] += line
        exons = []
        for exon in exons_extra: 
            exons.append(''.join([base for base in exon if base.isupper()]))
        return exons_extra, exons
    
    def find_all_guides(self, n): 
        self.fwd_guides = []
        prev_frame = 0
        prev_ind = 0
        for e, exon_extra in enumerate(self.exons_extra): 
            for i in range(len(exon_extra)-22): 
                frame = (i+prev_frame-20)%3
                ind = i-20+prev_ind
                self.fwd_guides.append([exon_extra[i:i+23], frame, ind, e])
            prev_frame = (prev_frame+len(exon_extra)-40)%3
            prev_ind += len(exon_extra)-40
            
        self.rev_guides = [[rev_complement(complements, 
                                           g[0])] + [(g[1]+1)%3] + [g[2]+22] + [g[3]] for g in self.fwd_guides]

# %%
def find_gRNAs(gene_object, mode, cas_type, target_codons=[], window=[4,8], PAM=None): 
    # mode: can be CBE or ABE, or just a list of 2 base edits ex ["C", "T"]
    # cas_type: Sp, SpG, SpRY
    # target_codons: list of codons that we want to make with our base edit
    # window: 4th to 8th bases inclusive by default, can be changed
    # PAM: optional field to input a custom PAM
    # Returns: a df of exon #, guides (23 bps), target (20 bps), fwd or rev, codon #, edit made
    
    # process mode
    if len(mode) == 3: 
        mode = base_editing_key[mode]
    assert len(mode) == 2
    
    # process PAM
    if PAM is None: 
        PAM = cas_key[cas_type]
    PAM_regex = process_PAM(PAM)
    
    # filter for PAM and contains editable base in window
    fwd_results = [g.copy() for g in gene_object.fwd_guides if PAM_regex.match(g[0][-len(PAM):]) and 
                                                    mode[0] in g[0][window[0]-1:window[1]]]
    for g in fwd_results: 
        original = g[0][1:12]
        mutated = g[0][1:window[0]-1] + g[0][window[0]-1:window[1]].replace(mode[0], 
                                                                            mode[1]) + g[0][window[1]:window[1]+4]
        assert(len(original)==len(mutated))
        
        start = (-1*(g[1]-1))+1
        original, mutated = original[start:start+9], mutated[start:start+9]
        original_aa, mutated_aa = '', ''
        edit, edit_ind = [], []
        for i in range(3): 
            if not original[i*3:(i+1)*3].isupper(): 
                continue
            original_aa += DNA_AA_map[original[i*3:(i+1)*3]]
            mutated_aa += DNA_AA_map[mutated[i*3:(i+1)*3]]
            if original_aa[-1] != mutated_aa[-1]: 
                edit.append(original_aa[-1] + ">" + mutated_aa[-1])
                edit_ind.append(int((g[2]+1+start+(i*3))/3))
                
        if len(edit) == 0: 
            edit.append('No Change')
        g.append(original_aa)
        g.append(mutated_aa)
        g.append(edit)
        g.append(edit_ind)
        g.append('fwd')
        
    # filter for PAM and contains editable base in window
    rev_results = [g.copy() for g in gene_object.rev_guides if PAM_regex.match(g[0][-len(PAM):]) and 
                                                    mode[0] in g[0][window[0]-1:window[1]]]
    for g in rev_results: 
        original = g[0][1:12]
        mutated = g[0][1:window[0]-1] + g[0][window[0]-1:window[1]].replace(mode[0], 
                                                                            mode[1]) + g[0][window[1]:window[1]+4]
        assert(len(original)==len(mutated))
        original = rev_complement(complements, original[g[1]:g[1]+9])
        mutated = rev_complement(complements, mutated[g[1]:g[1]+9])
        original_aa, mutated_aa = '', ''
        edit, edit_ind = [], []
        for i in range(3): 
            if not original[i*3:(i+1)*3].isupper(): 
                continue
            original_aa += DNA_AA_map[original[i*3:(i+1)*3]]
            mutated_aa += DNA_AA_map[mutated[i*3:(i+1)*3]]
            if original_aa[-1] != mutated_aa[-1]: 
                edit.append(original_aa[-1] + ">" + mutated_aa[-1])
                edit_ind.append(int((g[2]-5+(i*3))/3))
                
        if len(edit) == 0: 
            edit.append('No Change')
        g.append(original_aa)
        g.append(mutated_aa)
        g.append(edit)
        g.append(edit_ind)
        g.append('rev')
        assert(len(g)) == 9
        
    results = fwd_results + rev_results
    print(fwd_results)
    print(rev_results)
    return pd.DataFrame(results)
    
def process_PAM(PAM): 
    PAM = PAM.replace("G", "[gG]{1}")
    PAM = PAM.replace("C", "[cC]{1}")
    PAM = PAM.replace("T", "[tT]{1}")
    PAM = PAM.replace("A", "[aA]{1}")
    PAM = PAM.replace("N", "[acgtACGT]{1}")
    return re.compile("({})".format(PAM))

# %%
AR = Gene_BaseEditing(filepath="230408_AR_Input.fasta", 
                      output_dir="results"
                     )
AR.find_all_guides(n=23)
find_gRNAs(gene_object= AR, 
           mode=        "CBE", 
           cas_type=    "Sp"
          ).to_csv('230409_AR_BESpCBE_library.csv')
find_gRNAs(gene_object= AR, 
           mode=        "ABE", 
           cas_type=    "Sp"
          ).to_csv('230409_AR_BESpABE_library.csv')
# Out:
# [['AAGTGCAGTTAGGGCTGGGAAGG', 1, 4, 0, 'VQL', 'V.L', ['Q>.'], [3], 'fwd'], ['AGTGCAGTTAGGGCTGGGAAGGG', 2, 5, 0, 'VQL', 'V.L', ['Q>.'], [3], 'fwd'], ['CCGCCGTCCAAGACCTACCGAGG', 0, 39, 0, 'PSK', 'LFK', ['P>L', 'S>F'], [14, 15], 'fwd'], ['GCGCGAAGTGATCCAGAACCCGG', 2, 89, 0, 'REV', 'REV', ['No Change'], [], 'fwd'], ['TGATCCAGAACCCGGGCCCCAGG', 1, 97, 0, 'IQN', 'I.N', ['Q>.'], [34], 'fwd'], ['CCCGGGCCCCAGGCACCCAGAGG', 2, 107, 0, 'PGP', 'PGS', ['P>S'], [38], 'fwd'], ['GCCGCGAGCGCAGCACCTCCCGG', 0, 129, 0, 'ASA', 'VSA', ['A>V'], [44], 'fwd'], ['AGCAGCAAGAGACTAGCCCCAGG', 1, 232, 0, 'QQE', 'Q.E', ['Q>.'], [79], 'fwd'], ['CAGGCAGCAGCAGCAGCAGCAGG', 2, 251, 0, 'RQQ', 'R..', ['Q>.', 'Q>.'], [85, 86], 'fwd'], ['AGGCAGCAGCAGCAGCAGCAGGG', 0, 252, 0, 'QQQ', '..Q', ['Q>.', 'Q>.'], [85, 86], 'fwd'], ['GCAGCAGCAGCAGCAGGGTGAGG', 2, 257, 0, 'QQQ', 'Q..', ['Q>.', 'Q>.'], [87, 88], 'fwd'], ['CAGCAGCAGCAGGGTGAGGATGG', 0, 261, 0, 'QQQ', '..Q', ['Q>.', 'Q>.'], [88, 89], 'fwd'], ['TCTCCCCAAGCCCATCGTAGAGG', 0, 285, 0, 'PQA', 'F.A', ['P>F', 'Q>.'], [96, 97], 'fwd'], ['GCCCATCGTAGAGGCCCCACAGG', 0, 294, 0, 'HRR', 'YCR', ['H>Y', 'R>C'], [99, 100], 'fwd'], ['TAGAGGCCCCACAGGCTACCTGG', 2, 302, 0, 'RGP', 'RGS', ['P>S'], [103], 'fwd'], ['CCCCACAGGCTACCTGGTCCTGG', 2, 308, 0, 'PTG', 'PIG', ['T>I'], [104], 'fwd'], ['AGGCTACCTGGTCCTGGATGAGG', 2, 314, 0, 'GYL', 'GYL', ['No Change'], [], 'fwd'], ['GCAACCTTCACAGCCGCAGTCGG', 2, 341, 0, 'QPS', 'QFS', ['P>F'], [115], 'fwd'], ['TTCACAGCCGCAGTCGGCCCTGG', 2, 347, 0, 'SQP', 'S.S', ['Q>.', 'P>S'], [117, 118], 'fwd'], ['CCCAGAGCCTGGAGCCGCCGTGG', 2, 395, 0, 'PEP', 'PES', ['P>S'], [134], 'fwd'], ['AGCCGCCGTGGCCGCCAGCAAGG', 2, 407, 0, 'AAV', 'AVV', ['A>V'], [137], 'fwd'], ['GCCGCCGTGGCCGCCAGCAAGGG', 0, 408, 0, 'AVA', 'VVA', ['A>V'], [137], 'fwd'], ['CCGCCGTGGCCGCCAGCAAGGGG', 1, 409, 0, 'AVA', 'VVA', ['A>V'], [137], 'fwd'], ['GCAGCAGCTGCCAGCACCTCCGG', 2, 437, 0, 'QQL', 'Q.L', ['Q>.'], [147], 'fwd'], ['GCTGCCAGCACCTCCGGACGAGG', 2, 443, 0, 'LPA', 'LLA', ['P>L'], [149], 'fwd'], ['CCCATCCACGTTGTCCCTGCTGG', 2, 479, 0, 'PST', 'PFT', ['S>F'], [161], 'fwd'], ['CCATCCACGTTGTCCCTGCTGGG', 0, 480, 0, 'STL', 'FML', ['S>F', 'T>M'], [161, 162], 'fwd'], ['CTGCTGGGCCCCACTTTCCCCGG', 0, 495, 0, 'LGP', 'LGP', ['No Change'], [], 'fwd'], ['ACTCCTTCAGCAACAGCAGCAGG', 2, 575, 0, 'LLQ', 'LF.', ['L>F', 'Q>.'], [193, 194], 'fwd'], ['CAGCAGGAAGCAGTATCCGAAGG', 0, 591, 0, 'QEA', '.EA', ['Q>.'], [198], 'fwd'], ['GTATCCGAAGGCAGCAGCAGCGG', 0, 603, 0, 'SEG', 'FEG', ['S>F'], [202], 'fwd'], ['TATCCGAAGGCAGCAGCAGCGGG', 1, 604, 0, 'SEG', 'FEG', ['S>F'], [202], 'fwd'], ['GCAGCAGCAGCGGGAGAGCGAGG', 1, 613, 0, 'SSS', 'SSS', ['No Change'], [], 'fwd'], ['CAGCAGCAGCGGGAGAGCGAGGG', 2, 614, 0, 'SSS', 'SSS', ['No Change'], [], 'fwd'], ['CAGCAGCGGGAGAGCGAGGGAGG', 2, 617, 0, 'SSG', 'SSG', ['No Change'], [], 'fwd'], ['GGGAGAGCGAGGGAGGCCTCGGG', 0, 624, 0, 'RAR', 'RVR', ['A>V'], [210], 'fwd'], ['GGAGAGCGAGGGAGGCCTCGGGG', 1, 625, 0, 'RAR', 'RVR', ['A>V'], [210], 'fwd'], ['GAGAGCGAGGGAGGCCTCGGGGG', 2, 626, 0, 'RAR', 'RVR', ['A>V'], [210], 'fwd'], ['GGGGGCTCCCACTTCCTCCAAGG', 2, 644, 0, 'GAP', 'GVS', ['A>V', 'P>S'], [216, 217], 'fwd'], ['TCCTCCAAGGACAATTACTTAGG', 0, 657, 0, 'SKD', 'FKD', ['S>F'], [220], 'fwd'], ['CCTCCAAGGACAATTACTTAGGG', 1, 658, 0, 'SKD', 'FKD', ['S>F'], [220], 'fwd'], ['CTCCAAGGACAATTACTTAGGGG', 2, 659, 0, 'SKD', 'SKD', ['No Change'], [], 'fwd'], ['GACCATTTCTGACAACGCCAAGG', 2, 689, 0, 'TIS', 'TIS', ['No Change'], [], 'fwd'], ['CAACGCCAAGGAGTTGTGTAAGG', 2, 701, 0, 'NAK', 'NVK', ['A>V'], [235], 'fwd'], ['TAAGGCAGTGTCGGTGTCCATGG', 2, 719, 0, 'KAV', 'KVV', ['A>V'], [241], 'fwd'], ['AAGGCAGTGTCGGTGTCCATGGG', 0, 720, 0, 'AVS', 'VVS', ['A>V'], [241], 'fwd'], ['AGTGTCGGTGTCCATGGGCCTGG', 2, 725, 0, 'VSV', 'VLV', ['S>L'], [243], 'fwd'], ['GTGTCGGTGTCCATGGGCCTGGG', 0, 726, 0, 'SVS', 'LVS', ['S>L'], [243], 'fwd'], ['GGTGTCCATGGGCCTGGGTGTGG', 2, 731, 0, 'VSM', 'VFM', ['S>F'], [245], 'fwd'], ['GTCCATGGGCCTGGGTGTGGAGG', 2, 734, 0, 'SMG', 'SMG', ['No Change'], [], 'fwd'], ['GGGCCTGGGTGTGGAG ...
# [['TGCACTTCCATccttgagcttgg', 1, 10, 0, 'MEV', 'MKM', ['E>K', 'V>M'], [2, 3], 'rev'], ['AGGTCTTGGACGGCGGCCGAGGG', 0, 54, 0, 'SKT', 'SKT', ['No Change'], [], 'rev'], ['TAGGTCTTGGACGGCGGCCGAGG', 1, 55, 0, 'SKT', 'SKT', ['No Change'], [], 'rev'], ['CCTCGGTAGGTCTTGGACGGCGG', 1, 61, 0, 'TYR', 'TYQ', ['R>Q'], [20], 'rev'], ['GCTCCTCGGTAGGTCTTGGACGG', 1, 64, 0, 'YRG', 'YQK', ['R>Q', 'G>K'], [20, 21], 'rev'], ['GAAAGCTCCTCGGTAGGTCTTGG', 2, 68, 0, 'RGA', 'RET', ['G>E', 'A>T'], [22, 23], 'rev'], ['ATTCTGGAAAGCTCCTCGGTAGG', 2, 74, 0, 'AFQ', 'AFQ', ['No Change'], [], 'rev'], ['ACAGATTCTGGAAAGCTCCTCGG', 0, 78, 0, 'QNL', 'QNL', ['No Change'], [], 'rev'], ['GCACGCTCTGGAACAGATTCTGG', 0, 90, 0, 'QSV', 'QNM', ['S>N', 'V>M'], [29, 30], 'rev'], ['GGATCACTTCGCGCACGCTCTGG', 0, 102, 0, 'EVI', 'EII', ['V>I'], [33], 'rev'], ['GGTGCCTGGGGCCCGGGTTCTGG', 0, 123, 0, 'PRH', 'PKH', ['R>K'], [40], 'rev'], ['CCTCTGGGTGCCTGGGGCCCGGG', 0, 129, 0, 'HPE', 'HPK', ['E>K'], [43], 'rev'], ['GCCTCTGGGTGCCTGGGGCCCGG', 1, 130, 0, 'HPE', 'HPK', ['E>K'], [43], 'rev'], ['TCGCGGCCTCTGGGTGCCTGGGG', 0, 135, 0, 'EAA', 'ETT', ['A>T', 'A>T'], [44, 45], 'rev'], ['CTCGCGGCCTCTGGGTGCCTGGG', 1, 136, 0, 'EAA', 'ETT', ['A>T', 'A>T'], [44, 45], 'rev'], ['GCTCGCGGCCTCTGGGTGCCTGG', 2, 137, 0, 'EAA', 'EAT', ['A>T'], [46], 'rev'], ['GTGCTGCGCTCGCGGCCTCTGGG', 0, 144, 0, 'SAA', 'STT', ['A>T', 'A>T'], [47, 48], 'rev'], ['GGTGCTGCGCTCGCGGCCTCTGG', 1, 145, 0, 'SAA', 'STT', ['A>T', 'A>T'], [47, 48], 'rev'], ['AGCAGCAAACTGGCGCCGGGAGG', 1, 166, 0, 'SLL', 'SLL', ['No Change'], [], 'rev'], ['AGCAGCAGCAAACTGGCGCCGGG', 1, 169, 0, 'LLL', 'LLL', ['No Change'], [], 'rev'], ['CAGCAGCAGCAAACTGGCGCCGG', 2, 170, 0, 'LLL', 'LLL', ['No Change'], [], 'rev'], ['CTGCTGCAGCAGCAGCAAACTGG', 2, 176, 0, 'LLQ', 'LLQ', ['No Change'], [], 'rev'], ['GCTGCTGCTGCTGCTGCCTGGGG', 0, 270, 0, 'QQQ', 'QQQ', ['No Change'], [], 'rev'], ['TGCTGCTGCTGCTGCTGCCTGGG', 1, 271, 0, 'QQQ', 'QQQ', ['No Change'], [], 'rev'], ['CTGCTGCTGCTGCTGCTGCCTGG', 2, 272, 0, 'QQQ', 'QQQ', ['No Change'], [], 'rev'], ['GGGCCTCTACGATGGGCTTGGGG', 1, 310, 0, 'RRG', 'RKN', ['R>K', 'G>N'], [102, 103], 'rev'], ['GGGGCCTCTACGATGGGCTTGGG', 2, 311, 0, 'RRG', 'RKN', ['R>K', 'G>N'], [103, 104], 'rev'], ['TGGGGCCTCTACGATGGGCTTGG', 0, 312, 0, 'RGP', 'RNP', ['G>N'], [103], 'rev'], ['AGCCTGTGGGGCCTCTACGATGG', 0, 318, 0, 'PTG', 'PTS', ['G>S'], [106], 'rev'], ['CCAGGACCAGGTAGCCTGTGGGG', 0, 330, 0, 'LVL', 'LIL', ['V>I'], [109], 'rev'], ['TCCAGGACCAGGTAGCCTGTGGG', 1, 331, 0, 'LVL', 'LIL', ['V>I'], [109], 'rev'], ['ATCCAGGACCAGGTAGCCTGTGG', 2, 332, 0, 'LVL', 'LVL', ['No Change'], [], 'rev'], ['GCTGTTCCTCATCCAGGACCAGG', 0, 342, 0, 'EEQ', 'EKQ', ['E>K'], [113], 'rev'], ['AAGGTTGCTGTTCCTCATCCAGG', 0, 348, 0, 'QQP', 'QQP', ['No Change'], [], 'rev'], ['AGGGCCGACTGCGGCTGTGAAGG', 1, 367, 0, 'QSA', 'QST', ['A>T'], [122], 'rev'], ['TGGCACTCCAGGGCCGACTGCGG', 1, 376, 0, 'LEC', 'LKY', ['E>K', 'C>Y'], [124, 125], 'rev'], ['TCTCTCGGGGTGGCACTCCAGGG', 2, 386, 0, 'HPE', 'HPK', ['E>K'], [129], 'rev'], ['CTCTCTCGGGGTGGCACTCCAGG', 0, 387, 0, 'PER', 'PKR', ['E>K'], [128], 'rev'], ['GGACGCAACCTCTCTCGGGGTGG', 0, 396, 0, 'GCV', 'GYI', ['C>Y', 'V>I'], [131, 132], 'rev'], ['CTGGGACGCAACCTCTCTCGGGG', 0, 399, 0, 'CVP', 'CIP', ['V>I'], [132], 'rev'], ['TCTGGGACGCAACCTCTCTCGGG', 1, 400, 0, 'CVP', 'CIP', ['V>I'], [132], 'rev'], ['CCACGGCGGCTCCAGGCTCTGGG', 0, 417, 0, 'AAV', 'ATM', ['A>T', 'V>M'], [138, 139], 'rev'], ['GCCACGGCGGCTCCAGGCTCTGG', 1, 418, 0, 'AAV', 'ATM', ['A>T', 'V>M'], [138, 139], 'rev'], ['CTGGCGGCCACGGCGGCTCCAGG', 1, 424, 0, 'VAA', 'VTT', ['A>T', 'A>T'], [140, 141], 'rev'], ['CCCCTTGCTGGCGGCCACGGCGG', 2, 431, 0, 'ASK', 'ANK', ['S>N'], [143], 'rev'], ['CAGCCCCTTGCTGGCGGCCACGG', 2, 434, 0, 'SKG', 'SKK', ['G>K'], [145], 'rev'], ['CTGCGGCAGCCCCTTGCTGGCGG', 2, 440, 0, 'GLP', 'GLP', ['No Change'], [], 'rev'], ['CTGCTGCGGCAGCCCCTTGCTGG', 2, 443, 0, 'LPQ', 'LPQ', ['No Change'], [], 'rev'], ['GGAGGTGCTGGCAGCTGCTGCGG', 1, 457, 0, 'PAP', 'PTP', ['A>T'], [151], 'rev'], ['TCATCCTCGTCCGGAGGTGCTGG', 1, 469 ...
# [['tcaaggATGGAAGTGCAGTTAGG', 0, -6, 0, 'ME', 'VE', ['M>V'], [0], 'fwd'], ['caaggATGGAAGTGCAGTTAGGG', 1, -5, 0, 'ME', 'VE', ['M>V'], [0], 'fwd'], ['gATGGAAGTGCAGTTAGGGCTGG', 2, -1, 0, 'MEV', 'MGV', ['E>G'], [1], 'fwd'], ['ATGGAAGTGCAGTTAGGGCTGGG', 0, 0, 0, 'EVQ', 'GVQ', ['E>G'], [1], 'fwd'], ['AAGTGCAGTTAGGGCTGGGAAGG', 1, 4, 0, 'VQL', 'VRL', ['Q>R'], [3], 'fwd'], ['AGTGCAGTTAGGGCTGGGAAGGG', 2, 5, 0, 'VQL', 'VRL', ['Q>R'], [3], 'fwd'], ['GGCTGGGAAGGGTCTACCCTCGG', 1, 16, 0, 'LGR', 'LGR', ['No Change'], [], 'fwd'], ['GCGCGAAGTGATCCAGAACCCGG', 2, 89, 0, 'REV', 'RGV', ['E>G'], [31], 'fwd'], ['CGCGAAGTGATCCAGAACCCGGG', 0, 90, 0, 'EVI', 'GVI', ['E>G'], [31], 'fwd'], ['TGATCCAGAACCCGGGCCCCAGG', 1, 97, 0, 'IQN', 'IRN', ['Q>R'], [34], 'fwd'], ['GCCGCGAGCGCAGCACCTCCCGG', 0, 129, 0, 'ASA', 'AGA', ['S>G'], [45], 'fwd'], ['AGCAGCAAGAGACTAGCCCCAGG', 1, 232, 0, 'QQE', 'RRE', ['Q>R', 'Q>R'], [78, 79], 'fwd'], ['CAGGCAGCAGCAGCAGCAGCAGG', 2, 251, 0, 'RQQ', 'RRQ', ['Q>R'], [85], 'fwd'], ['AGGCAGCAGCAGCAGCAGCAGGG', 0, 252, 0, 'QQQ', 'RRQ', ['Q>R', 'Q>R'], [85, 86], 'fwd'], ['GCAGCAGCAGCAGCAGGGTGAGG', 2, 257, 0, 'QQQ', 'QRQ', ['Q>R'], [87], 'fwd'], ['CAGCAGCAGCAGGGTGAGGATGG', 0, 261, 0, 'QQQ', 'RRQ', ['Q>R', 'Q>R'], [88, 89], 'fwd'], ['TCTCCCCAAGCCCATCGTAGAGG', 0, 285, 0, 'PQA', 'PRA', ['Q>R'], [97], 'fwd'], ['GCCCATCGTAGAGGCCCCACAGG', 0, 294, 0, 'HRR', 'RRR', ['H>R'], [99], 'fwd'], ['TAGAGGCCCCACAGGCTACCTGG', 2, 302, 0, 'RGP', 'RGP', ['No Change'], [], 'fwd'], ['CCCCACAGGCTACCTGGTCCTGG', 2, 308, 0, 'PTG', 'PAG', ['T>A'], [104], 'fwd'], ['AGGCTACCTGGTCCTGGATGAGG', 2, 314, 0, 'GYL', 'GCL', ['Y>C'], [106], 'fwd'], ['GCAACCTTCACAGCCGCAGTCGG', 2, 341, 0, 'QPS', 'QPS', ['No Change'], [], 'fwd'], ['TTCACAGCCGCAGTCGGCCCTGG', 2, 347, 0, 'SQP', 'SRP', ['Q>R'], [117], 'fwd'], ['CTGGAGTGCCACCCCGAGAGAGG', 0, 366, 0, 'ECH', 'GCH', ['E>G'], [123], 'fwd'], ['CCCAGAGCCTGGAGCCGCCGTGG', 2, 395, 0, 'PEP', 'PGP', ['E>G'], [133], 'fwd'], ['GCAGCAGCTGCCAGCACCTCCGG', 2, 437, 0, 'QQL', 'QRL', ['Q>R'], [147], 'fwd'], ['GCTGCCAGCACCTCCGGACGAGG', 2, 443, 0, 'LPA', 'LPA', ['No Change'], [], 'fwd'], ['CCCATCCACGTTGTCCCTGCTGG', 2, 479, 0, 'PST', 'PSA', ['T>A'], [162], 'fwd'], ['CCATCCACGTTGTCCCTGCTGGG', 0, 480, 0, 'STL', 'SAL', ['T>A'], [162], 'fwd'], ['CCTTAAAGACATCCTGAGCGAGG', 2, 539, 0, 'LKD', 'LGD', ['K>G'], [181], 'fwd'], ['CAGCAGGAAGCAGTATCCGAAGG', 0, 591, 0, 'QEA', 'RGA', ['Q>R', 'E>G'], [198, 199], 'fwd'], ['GTATCCGAAGGCAGCAGCAGCGG', 0, 603, 0, 'SEG', 'SGG', ['E>G'], [203], 'fwd'], ['TATCCGAAGGCAGCAGCAGCGGG', 1, 604, 0, 'SEG', 'SGG', ['E>G'], [203], 'fwd'], ['GCAGCAGCAGCGGGAGAGCGAGG', 1, 613, 0, 'SSS', 'SGS', ['S>G'], [206], 'fwd'], ['CAGCAGCAGCGGGAGAGCGAGGG', 2, 614, 0, 'SSS', 'SGG', ['S>G', 'S>G'], [206, 207], 'fwd'], ['CAGCAGCGGGAGAGCGAGGGAGG', 2, 617, 0, 'SSG', 'SGG', ['S>G'], [207], 'fwd'], ['CGGGAGAGCGAGGGAGGCCTCGG', 2, 623, 0, 'GRA', 'GGA', ['R>G'], [209], 'fwd'], ['GGGAGAGCGAGGGAGGCCTCGGG', 0, 624, 0, 'RAR', 'GAR', ['R>G'], [209], 'fwd'], ['GGAGAGCGAGGGAGGCCTCGGGG', 1, 625, 0, 'RAR', 'RAR', ['No Change'], [], 'fwd'], ['GAGAGCGAGGGAGGCCTCGGGGG', 2, 626, 0, 'RAR', 'RAG', ['R>G'], [211], 'fwd'], ['TCCTCCAAGGACAATTACTTAGG', 0, 657, 0, 'SKD', 'SGD', ['K>G'], [221], 'fwd'], ['CCTCCAAGGACAATTACTTAGGG', 1, 658, 0, 'SKD', 'SGD', ['K>G'], [221], 'fwd'], ['CTCCAAGGACAATTACTTAGGGG', 2, 659, 0, 'SKD', 'SGD', ['K>G'], [221], 'fwd'], ['TCCAAGGACAATTACTTAGGGGG', 0, 660, 0, 'KDN', 'GGN', ['K>G', 'D>G'], [221, 222], 'fwd'], ['GACCATTTCTGACAACGCCAAGG', 2, 689, 0, 'TIS', 'TVS', ['I>V'], [231], 'fwd'], ['CAACGCCAAGGAGTTGTGTAAGG', 2, 701, 0, 'NAK', 'NAE', ['K>E'], [236], 'fwd'], ['TAAGGCAGTGTCGGTGTCCATGG', 2, 719, 0, 'KAV', 'KAV', ['No Change'], [], 'fwd'], ['AAGGCAGTGTCGGTGTCCATGGG', 0, 720, 0, 'AVS', 'AVS', ['No Change'], [], 'fwd'], ['GGTGTCCATGGGCCTGGGTGTGG', 2, 731, 0, 'VSM', 'VSV', ['M>V'], [246], 'fwd'], ['GTCCATGGGCCTGGGTGTGGAGG', 2, 734, 0, 'SMG', 'SVG', ['M>V'], [246], 'fwd'], ['GCGTTGGAGCATCTGAGTCCAGG', 0, 756, 0, 'LEH', 'LGH', ['E>G'], [254], 'fwd'], ['CGTTGGAGCATCTGAGTCCA ...
# [['TGCACTTCCATccttgagcttgg', 1, 10, 0, 'MEV', 'MEA', ['V>A'], [3], 'rev'], ['CCTCGGTAGGTCTTGGACGGCGG', 1, 61, 0, 'TYR', 'THR', ['Y>H'], [19], 'rev'], ['GAAAGCTCCTCGGTAGGTCTTGG', 2, 68, 0, 'RGA', 'RGA', ['No Change'], [], 'rev'], ['ATTCTGGAAAGCTCCTCGGTAGG', 2, 74, 0, 'AFQ', 'ASQ', ['F>S'], [24], 'rev'], ['ACAGATTCTGGAAAGCTCCTCGG', 0, 78, 0, 'QNL', 'QNL', ['No Change'], [], 'rev'], ['GGATCACTTCGCGCACGCTCTGG', 0, 102, 0, 'EVI', 'EAI', ['V>A'], [33], 'rev'], ['GCCGGGAGGTGCTGCGCTCGCGG', 2, 152, 0, 'APP', 'APP', ['No Change'], [], 'rev'], ['AGCAGCAAACTGGCGCCGGGAGG', 1, 166, 0, 'SLL', 'SPP', ['L>P', 'L>P'], [54, 55], 'rev'], ['AGCAGCAGCAAACTGGCGCCGGG', 1, 169, 0, 'LLL', 'LPP', ['L>P', 'L>P'], [55, 56], 'rev'], ['CAGCAGCAGCAAACTGGCGCCGG', 2, 170, 0, 'LLL', 'LPP', ['L>P', 'L>P'], [56, 57], 'rev'], ['CTGCTGCAGCAGCAGCAAACTGG', 2, 176, 0, 'LLQ', 'LPQ', ['L>P'], [58], 'rev'], ['CCAGGACCAGGTAGCCTGTGGGG', 0, 330, 0, 'LVL', 'LAL', ['V>A'], [109], 'rev'], ['TCCAGGACCAGGTAGCCTGTGGG', 1, 331, 0, 'LVL', 'LAP', ['V>A', 'L>P'], [109, 110], 'rev'], ['ATCCAGGACCAGGTAGCCTGTGG', 2, 332, 0, 'LVL', 'LAP', ['V>A', 'L>P'], [110, 111], 'rev'], ['AGGGCCGACTGCGGCTGTGAAGG', 1, 367, 0, 'QSA', 'QPA', ['S>P'], [121], 'rev'], ['TGGCACTCCAGGGCCGACTGCGG', 1, 376, 0, 'LEC', 'LER', ['C>R'], [125], 'rev'], ['GGACGCAACCTCTCTCGGGGTGG', 0, 396, 0, 'GCV', 'GRV', ['C>R'], [131], 'rev'], ['CTGGGACGCAACCTCTCTCGGGG', 0, 399, 0, 'CVP', 'CAP', ['V>A'], [132], 'rev'], ['TCTGGGACGCAACCTCTCTCGGG', 1, 400, 0, 'CVP', 'CAP', ['V>A'], [132], 'rev'], ['CTCTGGGACGCAACCTCTCTCGG', 2, 401, 0, 'CVP', 'CAP', ['V>A'], [133], 'rev'], ['GCCACGGCGGCTCCAGGCTCTGG', 1, 418, 0, 'AAV', 'AAA', ['V>A'], [139], 'rev'], ['CTGCGGCAGCCCCTTGCTGGCGG', 2, 440, 0, 'GLP', 'GPP', ['L>P'], [146], 'rev'], ['GCTGAGTCATCCTCGTCCGGAGG', 1, 475, 0, 'DDS', 'DDP', ['S>P'], [158], 'rev'], ['GCAGCTGAGTCATCCTCGTCCGG', 1, 478, 0, 'DSA', 'DPA', ['S>P'], [158], 'rev'], ['CAGCAGGGACAACGTGGATGGGG', 2, 500, 0, 'LSL', 'LSP', ['L>P'], [167], 'rev'], ['CCAGCAGGGACAACGTGGATGGG', 0, 501, 0, 'SLL', 'SPL', ['L>P'], [166], 'rev'], ['CCCAGCAGGGACAACGTGGATGG', 1, 502, 0, 'SLL', 'SPP', ['L>P', 'L>P'], [166, 167], 'rev'], ['GGGGCCCAGCAGGGACAACGTGG', 2, 506, 0, 'LLG', 'LPG', ['L>P'], [168], 'rev'], ['GGGGAAAGTGGGGCCCAGCAGGG', 2, 515, 0, 'PTF', 'PTP', ['F>P'], [172], 'rev'], ['CGGGGAAAGTGGGGCCCAGCAGG', 0, 516, 0, 'TFP', 'TPP', ['F>P'], [171], 'rev'], ['TGCTTAAGCCGGGGAAAGTGGGG', 0, 525, 0, 'GLS', 'GPS', ['L>P'], [174], 'rev'], ['CTGCTTAAGCCGGGGAAAGTGGG', 1, 526, 0, 'GLS', 'GPS', ['L>P'], [174], 'rev'], ['GCTGCTTAAGCCGGGGAAAGTGG', 2, 527, 0, 'GLS', 'GSS', ['L>S'], [175], 'rev'], ['CGGAGCAGCTGCTTAAGCCGGGG', 0, 534, 0, 'SCS', 'SRP', ['C>R', 'S>P'], [177, 178], 'rev'], ['GCGGAGCAGCTGCTTAAGCCGGG', 1, 535, 0, 'SCS', 'SRP', ['C>R', 'S>P'], [177, 178], 'rev'], ['AGCGGAGCAGCTGCTTAAGCCGG', 2, 536, 0, 'SCS', 'SCP', ['S>P'], [179], 'rev'], ['CAGGATGTCTTTAAGGTCAGCGG', 2, 554, 0, 'KDI', 'KDT', ['I>T'], [185], 'rev'], ['CTGAAGGAGTTGCATGGTGCTGG', 2, 584, 0, 'QLL', 'QPP', ['L>P', 'L>P'], [194, 195], 'rev'], ['GGAGGAAGTGGGAGCCCCCGAGG', 2, 662, 0, 'PTS', 'PTP', ['S>P'], [221], 'rev'], ['GTAATTGTCCTTGGAGGAAGTGG', 2, 674, 0, 'KDN', 'KDN', ['No Change'], [], 'rev'], ['CCCTAAGTAATTGTCCTTGGAGG', 2, 680, 0, 'NYL', 'NYP', ['L>P'], [227], 'rev'], ['GCCCCCTAAGTAATTGTCCTTGG', 2, 683, 0, 'YLG', 'YSG', ['L>S'], [227], 'rev'], ['CGCCTCCACACCCAGGCCCATGG', 2, 758, 0, 'GVE', 'GAE', ['V>A'], [252], 'rev'], ['GCTCCAACGCCTCCACACCCAGG', 0, 765, 0, 'ALE', 'APE', ['L>P'], [254], 'rev'], ['GGGTGGAACTCCCAAAAGTGGGG', 2, 830, 0, 'GVP', 'GAP', ['V>A'], [276], 'rev'], ['CGGGTGGAACTCCCAAAAGTGGG', 0, 831, 0, 'VPP', 'VPP', ['No Change'], [], 'rev'], ['CAAGGAGTGGGACGCACAGCGGG', 1, 850, 0, 'PTP', 'PTP', ['No Change'], [], 'rev'], ['ACAAGGAGTGGGACGCACAGCGG', 2, 851, 0, 'PTP', 'PTP', ['No Change'], [], 'rev'], ['GCCAATGGGGCACAAGGAGTGGG', 1, 862, 0, 'APL', 'APP', ['L>P'], [287], 'rev'], ['GGCCAATGGGGCACAAGGAGTGG', 2, 863, 0, 'APL', 'APP', ['L>P'], [288], 'rev'], ['TAGCAGAGAACCTTTGCATTCGG', 2, 884, 0 ...
